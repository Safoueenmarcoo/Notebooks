# %%
import gymnasium as gym
import jax.numpy as jnp
import numpy as np
import jax.random as jrandom
from utils_v2 import KalmanFilter
from stable_baselines3 import PPO
from jax import grad, test_util

# %%
delta_t = 0.1
m = 0.1
M = 1
g = 9.8
le = 0.5
A = jnp.array(
    [
        [0, 1, 0, 0],
        [0, 0, m * g * delta_t / M, 0],
        [0, 0, 0, 1],
        [0, 0, (m + M) * g * delta_t / (M * le), 0],
    ]
)

# A=jnp.array([[1,delta_t,0,0],
#             [0,1,m*g*delta_t/M,0],
#             [0,0,1,delta_t],
#             [0,0,(m+M)*g*delta_t/(M*l),1]])

B = jnp.array([[0], [delta_t / M], [0], [delta_t / (M * le)]])

B_0 = jnp.ones((4, 1))


H = jnp.eye(4)

R = jnp.eye(H.shape[0]) * 0.005
C = H
Q = jnp.eye(A.shape[0]) * 0.005
mean = 0
std_dev = 0.005
# Q=jrandom.normal(key, shape=(A.shape[0],1)) * std_dev + mean     #FAILED
P = jnp.ones(A.shape[0])
key = jrandom.PRNGKey(42)
Z = jrandom.normal(key, shape=(C.shape[0], 1)) * std_dev + mean
w_k = jnp.ones((A.shape[0], 1)) * 0.005
# w_k=jrandom.normal(key, shape=(A.shape[0],1)) * std_dev + mean    #FAILED

# %%
class KFOptimiser(gym.Env):
    def __init__(self, control_model, lr=0.01, lr_decay=0.9995, min_lr=0.001):
        super(KFOptimiser, self).__init__()

        self.env = gym.make("CartPole-v1")
        self.env._max_episode_steps = 1000

        self.B_0 = jnp.zeros((4, 1))

        self.kf = KalmanFilter(
            jnp.expand_dims(self.env.reset()[0], axis=-1),
            A,
            self.B_0,
            H,
            R,
            C,
            Q,
            Z,
            w_k,
            P,
        )

        self.action_space = gym.spaces.Box(
            low=-1, high=1, shape=self.kf.B.flatten().shape
        )

        low = np.append(
            jnp.append(self.env.observation_space.low, self.env.observation_space.low),
            jnp.full(self.B_0.flatten().shape, -3),
        )
        self.observation_space = gym.spaces.Box(low, -low)

        self.control_model = control_model
        self.lr = lr
        self.lr_decay = lr_decay
        self.min_lr = min_lr

    def reset(self, seed=None, **kwargs):
        state = self.env.reset()[0]  # 4-dim
        self.kf.reset()  # 4-dim

        # approach 1: reset B at each episode
        self.kf.B = self.B_0  # 2

        # approach 2: don't reset at each episode
        # do nothing  #1

        # approach 3: Perturb B slightly at the start of each episode
        self.kf.B += np.random.normal(
            0, 0.3, size=self.kf.B.shape
        )  # 3 very bad results

        self.state = np.append(
            jnp.append(state, self.kf.x_0), self.kf.B
        )  # 12-dim (4x true state, 4x estimated state, 4x B)

        return self.state, {}  # 12-dim

    def loss_fn(self, B, true_state, kf_state):
        error = true_state - kf_state
        return jnp.mean(error**2)

    def step(self, action):
        action = jnp.expand_dims(action, axis=-1)  # + np.random.normal(0, 0.1)  # 4-dim

        u = self.control_model.predict(self.state[:4])[0]  # first 4x of true states
        true_state, _, done, truncuated, _ = self.env.step(u)

        u_k = jnp.array([[u if u == 1 else -1]])

        # true_B=true_state-self.kf.A @ self.state[:4] / u_k

        true_B = (
            true_state
            - self.state[:4]
            - delta_t * self.kf.A @ self.state[:4]
            - self.kf.w_k
        ) / (u_k * delta_t)

        self.kf.predict(u_k)

        self.state = np.append(
            jnp.append(true_state, self.kf.update(true_state)), self.kf.B
        )

        error = true_state - self.state[4:8]

        grad_loss_fn = grad(self.loss_fn)

        gradient = grad_loss_fn(self.kf.B, true_state, self.state[4:8])

        # b_error=b_error*jnp.array([[1],[1],[1],[5]])

        if self.lr > self.min_lr:
            self.lr *= self.lr_decay
            self.lr = max(self.min_lr, self.lr)

        # self.kf.B+=action*self.lr
        # + jnp.expand_dims(error,axis=-1)*self.beta
        # + b_error*self.beta
        previous_b = self.kf.B

        self.kf.B += self.lr * action - (1 - self.lr) * gradient

        self.kf.B = jnp.clip(
            self.kf.B,
            jnp.expand_dims(self.observation_space.low[8:], axis=-1),
            jnp.expand_dims(self.observation_space.high[8:], axis=-1),
        )
        B_change_penalty = jnp.linalg.norm(self.kf.B - previous_b)
        b_error = true_B - self.kf.B

        # error=error*jnp.array([[1],[1],[1],[3]])

        error = jnp.mean(error**2)

        b_error = jnp.mean(b_error.flatten() ** 2)

        return self.state, -error - 0.1 * B_change_penalty, done, truncuated, {}

# %%
model = PPO.load("ppo_cartpole_100k_noKF")

# %%
# cpu: 50mins
# cuda: 58mins
try:
    env = KFOptimiser(model)
    log_dir = "logs"
    model1 = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_dir, device="cpu")
    model1.learn(total_timesteps=300_000, tb_log_name="PPO_grad_b_change_pen")
except KeyboardInterrupt:
    print("cut")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO_grad_b_change_pen_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -17.4    |
# | time/              |          |
# |    fps             | 104      |
# |    iterations      | 1        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -16          |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 2            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0050049694 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | -5.36        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0217      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00486     |
# |    std                  | 1.01         |
# |    value_loss           | 0.00649      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -18          |
# | time/                   |              |
# |    fps                  | 88           |
# |    iterations           | 3            |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0067378543 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.71        |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0123      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00704     |
# |    std                  | 1.01         |
# |    value_loss           | 0.00285      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -17.6       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 4           |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007446904 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0368     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00636    |
# |    std                  | 1.01        |
# |    value_loss           | 0.00638     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -16.5       |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 5           |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008374511 |
# |    clip_fraction        | 0.0755      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00831    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00966    |
# |    std                  | 1.02        |
# |    value_loss           | 0.00128     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -18.7        |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 6            |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0076029655 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.75        |
# |    explained_variance   | 0.549        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00706      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00807     |
# |    std                  | 1.02         |
# |    value_loss           | 0.00172      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -18.1        |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 7            |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0076200236 |
# |    clip_fraction        | 0.0652       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.76        |
# |    explained_variance   | 0.852        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00452     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00761     |
# |    std                  | 1.02         |
# |    value_loss           | 0.00482      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -16.5       |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 8           |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005414827 |
# |    clip_fraction        | 0.0251      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00553    |
# |    std                  | 1.03        |
# |    value_loss           | 0.00128     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -15.7       |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 9           |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008584149 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00694     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00903    |
# |    std                  | 1.03        |
# |    value_loss           | 0.000305    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -17.2       |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 10          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004974559 |
# |    clip_fraction        | 0.038       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0117     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00769    |
# |    std                  | 1.03        |
# |    value_loss           | 0.00143     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -17.5        |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 11           |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0070993733 |
# |    clip_fraction        | 0.0603       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.8         |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00663      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00696     |
# |    std                  | 1.03         |
# |    value_loss           | 0.00499      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -17.3       |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 12          |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007943014 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0313      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0081     |
# |    std                  | 1.04        |
# |    value_loss           | 0.00112     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -17.3       |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 13          |
# |    time_elapsed         | 338         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007802819 |
# |    clip_fraction        | 0.0633      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0109     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0056     |
# |    std                  | 1.04        |
# |    value_loss           | 0.00134     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -16.6        |
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 14           |
# |    time_elapsed         | 366          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0063514425 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.84        |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0107       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00589     |
# |    std                  | 1.05         |
# |    value_loss           | 0.000649     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -16.8        |
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 15           |
# |    time_elapsed         | 393          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0062367255 |
# |    clip_fraction        | 0.0489       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.88        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00841      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00639     |
# |    std                  | 1.06         |
# |    value_loss           | 0.000394     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -16.5       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 16          |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006197405 |
# |    clip_fraction        | 0.0615      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.89       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0126     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00573    |
# |    std                  | 1.05        |
# |    value_loss           | 0.00418     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -17         |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 17          |
# |    time_elapsed         | 446         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005848862 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.88       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0271     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00789    |
# |    std                  | 1.05        |
# |    value_loss           | 0.001       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -17         |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 18          |
# |    time_elapsed         | 472         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006150175 |
# |    clip_fraction        | 0.0557      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.88       |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00109    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00594    |
# |    std                  | 1.05        |
# |    value_loss           | 0.00831     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -17         |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 19          |
# |    time_elapsed         | 500         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007350978 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.87       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0222     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00586    |
# |    std                  | 1.05        |
# |    value_loss           | 0.000974    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -16.6       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 20          |
# |    time_elapsed         | 525         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008376558 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.87       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0093     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00825    |
# |    std                  | 1.05        |
# |    value_loss           | 0.000299    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -17.3        |
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 21           |
# |    time_elapsed         | 553          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0040779766 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.86        |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000949    |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00183     |
# |    std                  | 1.05         |
# |    value_loss           | 0.00164      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -17.3        |
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 22           |
# |    time_elapsed         | 579          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0066315746 |
# |    clip_fraction        | 0.0617       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.86        |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000781    |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00523     |
# |    std                  | 1.05         |
# |    value_loss           | 0.00695      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -17.4        |
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 23           |
# |    time_elapsed         | 606          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0065909806 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.85        |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0145      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00608     |
# |    std                  | 1.04         |
# |    value_loss           | 0.00342      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -17.1        |
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 24           |
# |    time_elapsed         | 632          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0076536317 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.86        |
# |    explained_variance   | 0.707        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000222    |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00468     |
# |    std                  | 1.05         |
# |    value_loss           | 0.00293      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -17.6        |
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 25           |
# |    time_elapsed         | 660          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0074328203 |
# |    clip_fraction        | 0.0609       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.89        |
# |    explained_variance   | 0.715        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00691     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00533     |
# |    std                  | 1.06         |
# |    value_loss           | 0.000574     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -17.2       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 26          |
# |    time_elapsed         | 687         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005090691 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.91       |
# |    explained_variance   | 0.0141      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00877    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0046     |
# |    std                  | 1.06        |
# |    value_loss           | 0.0053      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -17.8        |
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 27           |
# |    time_elapsed         | 716          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0048661567 |
# |    clip_fraction        | 0.0358       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.95        |
# |    explained_variance   | 0.568        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0212      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00467     |
# |    std                  | 1.08         |
# |    value_loss           | 0.000898     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -18.3       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 28          |
# |    time_elapsed         | 742         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.006860935 |
# |    clip_fraction        | 0.0468      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.99       |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00792     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00363    |
# |    std                  | 1.08        |
# |    value_loss           | 0.00773     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -18.3       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 29          |
# |    time_elapsed         | 769         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.005827583 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.96       |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0122     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00716    |
# |    std                  | 1.06        |
# |    value_loss           | 0.00591     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -18.8       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 30          |
# |    time_elapsed         | 796         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.006850826 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.93       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.031      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00776    |
# |    std                  | 1.07        |
# |    value_loss           | 0.00236     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -19         |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 31          |
# |    time_elapsed         | 822         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008527521 |
# |    clip_fraction        | 0.0952      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.94       |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00538     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00749    |
# |    std                  | 1.07        |
# |    value_loss           | 0.0185      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -18.8       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 32          |
# |    time_elapsed         | 849         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005365728 |
# |    clip_fraction        | 0.0454      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.96       |
# |    explained_variance   | -0.011      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00625    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00448    |
# |    std                  | 1.08        |
# |    value_loss           | 0.00508     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -18.5       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 33          |
# |    time_elapsed         | 870         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.006201527 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.97       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00844    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00608    |
# |    std                  | 1.08        |
# |    value_loss           | 0.00207     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -19.2       |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 34          |
# |    time_elapsed         | 887         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006813978 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.98       |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00294    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00724    |
# |    std                  | 1.08        |
# |    value_loss           | 0.0032      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -19         |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 35          |
# |    time_elapsed         | 905         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.006369598 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.97       |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00454    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00383    |
# |    std                  | 1.07        |
# |    value_loss           | 0.00286     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -19.3        |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 36           |
# |    time_elapsed         | 922          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0075639174 |
# |    clip_fraction        | 0.0682       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.96        |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00574      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00761     |
# |    std                  | 1.07         |
# |    value_loss           | 0.00746      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -20         |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 37          |
# |    time_elapsed         | 938         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.005406853 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.96       |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0178     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00475    |
# |    std                  | 1.08        |
# |    value_loss           | 0.0268      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 38           |
# |    time_elapsed         | 957          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0062895226 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.99        |
# |    explained_variance   | -9.2         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00315      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00939     |
# |    std                  | 1.09         |
# |    value_loss           | 0.0205       |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | -20.3    |
# | time/                   |          |
# |    fps                  | 82       |
# |    iterations           | 39       |
# |    time_elapsed         | 973      |
# |    total_timesteps      | 79872    |
# | train/                  |          |
# |    approx_kl            | 0.006488 |
# |    clip_fraction        | 0.052    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -6.03    |
# |    explained_variance   | -0.005   |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0212  |
# |    n_updates            | 380      |
# |    policy_gradient_loss | -0.00468 |
# |    std                  | 1.1      |
# |    value_loss           | 0.014    |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -20.1        |
# | time/                   |              |
# |    fps                  | 82           |
# |    iterations           | 40           |
# |    time_elapsed         | 990          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0058540916 |
# |    clip_fraction        | 0.0616       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.04        |
# |    explained_variance   | 0.436        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00857     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00608     |
# |    std                  | 1.09         |
# |    value_loss           | 0.00128      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -20.1       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 41          |
# |    time_elapsed         | 1008        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.005842932 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.02       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00445    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0051     |
# |    std                  | 1.09        |
# |    value_loss           | 0.00103     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -20          |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 42           |
# |    time_elapsed         | 1026         |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0072197667 |
# |    clip_fraction        | 0.0626       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.02        |
# |    explained_variance   | 0.841        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000872     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00623     |
# |    std                  | 1.09         |
# |    value_loss           | 0.00608      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -20         |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 43          |
# |    time_elapsed         | 1043        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005847372 |
# |    clip_fraction        | 0.0483      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.03       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0251      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00536    |
# |    std                  | 1.09        |
# |    value_loss           | 0.00113     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -19.8        |
# | time/                   |              |
# |    fps                  | 85           |
# |    iterations           | 44           |
# |    time_elapsed         | 1059         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0072573526 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.05        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0187      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00678     |
# |    std                  | 1.1          |
# |    value_loss           | 0.00131      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 45          |
# |    time_elapsed         | 1076        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007229586 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.09       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00951    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00588    |
# |    std                  | 1.12        |
# |    value_loss           | 0.00235     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -19.7       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 46          |
# |    time_elapsed         | 1094        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011735031 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.1        |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0149     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 1.11        |
# |    value_loss           | 0.000392    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -19.5        |
# | time/                   |              |
# |    fps                  | 86           |
# |    iterations           | 47           |
# |    time_elapsed         | 1112         |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0063465834 |
# |    clip_fraction        | 0.0553       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.1         |
# |    explained_variance   | -4.28        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00542      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00482     |
# |    std                  | 1.12         |
# |    value_loss           | 0.00312      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -19.3      |
# | time/                   |            |
# |    fps                  | 87         |
# |    iterations           | 48         |
# |    time_elapsed         | 1129       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.00435055 |
# |    clip_fraction        | 0.0435     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.12      |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00211   |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.00412   |
# |    std                  | 1.12       |
# |    value_loss           | 0.000335   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -19         |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 49          |
# |    time_elapsed         | 1146        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.005316357 |
# |    clip_fraction        | 0.0392      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.14       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00384     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.005      |
# |    std                  | 1.12        |
# |    value_loss           | 0.000332    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -18.9        |
# | time/                   |              |
# |    fps                  | 88           |
# |    iterations           | 50           |
# |    time_elapsed         | 1163         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0058796126 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.17        |
# |    explained_variance   | 0.888        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000951     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00796     |
# |    std                  | 1.14         |
# |    value_loss           | 0.000479     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -18.9        |
# | time/                   |              |
# |    fps                  | 88           |
# |    iterations           | 51           |
# |    time_elapsed         | 1179         |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0055922186 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.19        |
# |    explained_variance   | 0.84         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.023       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00516     |
# |    std                  | 1.14         |
# |    value_loss           | 0.000689     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -18.7       |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 52          |
# |    time_elapsed         | 1196        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.007979867 |
# |    clip_fraction        | 0.0687      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.18       |
# |    explained_variance   | 0.214       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00235    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00908    |
# |    std                  | 1.13        |
# |    value_loss           | 0.000933    |
# -----------------------------------------
# ...
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 1.26        |
# |    value_loss           | 0.000313    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -14.6        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 131          |
# |    time_elapsed         | 2522         |
# |    total_timesteps      | 268288       |
# | train/                  |              |
# |    approx_kl            | 0.0060419734 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.58        |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000155     |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | -0.00412     |
# |    std                  | 1.26         |
# |    value_loss           | 0.00033      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -14.5        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 132          |
# |    time_elapsed         | 2539         |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0070583527 |
# |    clip_fraction        | 0.0651       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.58        |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0194      |
# |    n_updates            | 1310         |
# |    policy_gradient_loss | -0.00745     |
# |    std                  | 1.26         |
# |    value_loss           | 0.000352     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -14.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 133          |
# |    time_elapsed         | 2556         |
# |    total_timesteps      | 272384       |
# | train/                  |              |
# |    approx_kl            | 0.0062376484 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.57        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0164      |
# |    n_updates            | 1320         |
# |    policy_gradient_loss | -0.0063      |
# |    std                  | 1.25         |
# |    value_loss           | 0.00027      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -14.4       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 134         |
# |    time_elapsed         | 2573        |
# |    total_timesteps      | 274432      |
# | train/                  |             |
# |    approx_kl            | 0.007323644 |
# |    clip_fraction        | 0.0798      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.56       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0091     |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | -0.00914    |
# |    std                  | 1.26        |
# |    value_loss           | 0.000308    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -14         |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 135         |
# |    time_elapsed         | 2590        |
# |    total_timesteps      | 276480      |
# | train/                  |             |
# |    approx_kl            | 0.007388987 |
# |    clip_fraction        | 0.0651      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.58       |
# |    explained_variance   | 0.823       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00947    |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | -0.00776    |
# |    std                  | 1.26        |
# |    value_loss           | 0.000514    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -14         |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 136         |
# |    time_elapsed         | 2606        |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.007039345 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.61       |
# |    explained_variance   | -0.0776     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0289     |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | -0.00907    |
# |    std                  | 1.28        |
# |    value_loss           | 0.000814    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -13.9       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 137         |
# |    time_elapsed         | 2624        |
# |    total_timesteps      | 280576      |
# | train/                  |             |
# |    approx_kl            | 0.006144076 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.63       |
# |    explained_variance   | 0.665       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0337      |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.00591    |
# |    std                  | 1.28        |
# |    value_loss           | 0.000719    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -13.4       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 138         |
# |    time_elapsed         | 2640        |
# |    total_timesteps      | 282624      |
# | train/                  |             |
# |    approx_kl            | 0.005524826 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.64       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0189     |
# |    n_updates            | 1370        |
# |    policy_gradient_loss | -0.00482    |
# |    std                  | 1.29        |
# |    value_loss           | 0.000269    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -13.1       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 139         |
# |    time_elapsed         | 2657        |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.005202325 |
# |    clip_fraction        | 0.0793      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.66       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00187    |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.0078     |
# |    std                  | 1.29        |
# |    value_loss           | 0.000225    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -13          |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 140          |
# |    time_elapsed         | 2674         |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0081363525 |
# |    clip_fraction        | 0.0988       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.63        |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000396    |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.00966     |
# |    std                  | 1.27         |
# |    value_loss           | 0.000259     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -12.7        |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 141          |
# |    time_elapsed         | 2691         |
# |    total_timesteps      | 288768       |
# | train/                  |              |
# |    approx_kl            | 0.0070478376 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.6         |
# |    explained_variance   | 0.913        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00586     |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -0.00502     |
# |    std                  | 1.27         |
# |    value_loss           | 0.000223     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -12.8      |
# | time/                   |            |
# |    fps                  | 107        |
# |    iterations           | 142        |
# |    time_elapsed         | 2708       |
# |    total_timesteps      | 290816     |
# | train/                  |            |
# |    approx_kl            | 0.00607644 |
# |    clip_fraction        | 0.0679     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.62      |
# |    explained_variance   | 0.805      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0167    |
# |    n_updates            | 1410       |
# |    policy_gradient_loss | -0.00761   |
# |    std                  | 1.28       |
# |    value_loss           | 0.000813   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -12.7       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 143         |
# |    time_elapsed         | 2724        |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.006020155 |
# |    clip_fraction        | 0.0455      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.64       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00777    |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.00482    |
# |    std                  | 1.28        |
# |    value_loss           | 0.000587    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -12.7       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 144         |
# |    time_elapsed         | 2742        |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.005841494 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.65       |
# |    explained_variance   | 0.261       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000602    |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | -0.00656    |
# |    std                  | 1.29        |
# |    value_loss           | 0.00122     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -12.7       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 145         |
# |    time_elapsed         | 2758        |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.007333315 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.67       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0271     |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | -0.0065     |
# |    std                  | 1.3         |
# |    value_loss           | 0.00131     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -12.9       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 146         |
# |    time_elapsed         | 2775        |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.005806151 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.69       |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0108      |
# |    n_updates            | 1450        |
# |    policy_gradient_loss | -0.00403    |
# |    std                  | 1.3         |
# |    value_loss           | 0.000498    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -12.8        |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 147          |
# |    time_elapsed         | 2792         |
# |    total_timesteps      | 301056       |
# | train/                  |              |
# |    approx_kl            | 0.0044918563 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.68        |
# |    explained_variance   | 0.935        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0119       |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | -0.00323     |
# |    std                  | 1.29         |
# |    value_loss           | 0.00139      |
# ------------------------------------------

# %%
from tqdm import tqdm

episodes = 10
x = []
for ep in tqdm(range(1, episodes + 1), ascii=True, unit="episodes"):
    state = env.reset()[0]
    while True:
        # env.render()
        action = model1.predict(state)[0]
        state, reward, done, truncuated, info = env.step(action)
        if done or truncuated:
            break
    h = env.kf.B - B
    x.append(h)
jnp.mean(jnp.array(x), axis=0)
# Out:
# 100%|##########| 10/10 [01:46<00:00, 10.66s/episodes]
# Array([[ 0.08263567],
#        [-0.04436978],
#        [-0.17011417],
#        [-0.5063559 ]], dtype=float32)

# %%
class KFOptimiser_A(gym.Env):
    def __init__(self, control_model, lr=0.01, beta=0.001):
        super(KFOptimiser_A, self).__init__()

        self.env = gym.make("CartPole-v1")
        self.env._max_episode_steps = 1000

        self.A_0 = jnp.zeros((4, 4))

        self.kf = KalmanFilter(
            jnp.expand_dims(self.env.reset()[0], axis=-1),
            self.A_0,
            B,
            H,
            R,
            C,
            Q,
            Z,
            w_k,
            P,
        )

        self.action_space = gym.spaces.Box(
            low=-1, high=1, shape=self.A_0.flatten().shape
        )

        low = np.append(
            jnp.append(self.env.observation_space.low, self.env.observation_space.low),
            jnp.full(self.A_0.flatten().shape, -3),
        )
        self.observation_space = gym.spaces.Box(low, -low)

        self.control_model = control_model
        self.lr = lr
        self.beta = beta

    def reset(self, seed=None, **kwargs):
        state = self.env.reset()[0]  # 4-dim
        self.kf.reset()  # 4-dim

        # approach 1: reset B at each episode
        self.kf.A = self.A_0  # 2

        # approach 2: don't reset at each episode
        # do nothing  #1

        # approach 3: Perturb B slightly at the start of each episode
        self.kf.A += np.random.normal(0, 0.1, size=self.kf.A.shape)

        self.state = np.append(
            jnp.append(state, self.kf.x_0), self.kf.A.flatten()
        )  # 24-dim (4x true state, 4x estimated state, 16x A)

        return self.state, {}  # 24-dim

    def step(self, action):
        action = jnp.expand_dims(action, axis=-1) + np.random.normal(0, 0.1)  # 4-dim

        u = self.control_model.predict(self.state[:4])[0]  # fist 4x of true states

        true_state, _, done, truncuated, _ = self.env.step(u)

        u_k = jnp.array([[u if u == 1 else -1]])

        true_A = (true_state - self.state[:4] - delta_t * self.kf.B @ u_k) / self.state[
            :4
        ]

        self.kf.predict(u_k)

        self.state = np.append(
            jnp.append(true_state, self.kf.update(true_state)), self.kf.A.flatten()
        )

        error = self.state[:4] - self.state[4:8]

        a_error = true_A - self.kf.A

        # b_error=b_error*jnp.array([[1],[1],[1],[5]])

        update = self.kf.A.reshape((16, 1)) + action * self.lr
        +jnp.expand_dims(error, axis=-1) * self.beta
        +a_error.flatten() * self.beta

        self.kf.A = jnp.clip(
            update,
            jnp.expand_dims(self.observation_space.low[8:], axis=-1),
            jnp.expand_dims(self.observation_space.high[8:], axis=-1),
        ).reshape((4, 4))

        total_error = jnp.mean(error**2)

        # total_b_error=jnp.mean(b_error.flatten()**2) #B matrix error didn't work well

        return self.state, -total_error, done, truncuated, {}

# %%
env = KFOptimiser_A(model)
model2 = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_dir)
model2.learn(total_timesteps=300_000, tb_log_name="PPO_A")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO_A_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    fps             | 235      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -10.7       |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 2           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008822694 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | -0.578      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.997       |
# |    value_loss           | 0.00264     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -10.5       |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 3           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012037428 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00922    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.994       |
# |    value_loss           | 0.000945    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -10.7       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 4           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012982685 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0228     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.992       |
# |    value_loss           | 0.00206     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -11.1        |
# | time/                   |              |
# |    fps                  | 221          |
# |    iterations           | 5            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0141374115 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.6        |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0465      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0201      |
# |    std                  | 0.993        |
# |    value_loss           | 0.000713     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -11.2       |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 6           |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011746548 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.422       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0433     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.99        |
# |    value_loss           | 0.0104      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -11.1       |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 7           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012945417 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.99        |
# |    value_loss           | 0.000807    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -11.2       |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 8           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012735289 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0415     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0206     |
# |    std                  | 0.99        |
# |    value_loss           | 0.00494     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -11.1       |
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 9           |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012979722 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0272     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0199     |
# |    std                  | 0.989       |
# |    value_loss           | 0.000576    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -10.8       |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 10          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013500196 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0275     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 0.989       |
# |    value_loss           | 0.000544    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -10.6       |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 11          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012945866 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00337     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.987       |
# |    value_loss           | 0.000392    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -10.5       |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 12          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012158712 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0313     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.986       |
# |    value_loss           | 0.000757    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -10.3       |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 13          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014415169 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0219     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.982       |
# |    value_loss           | 0.000446    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -10.2       |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 14          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.012949752 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0122     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0191     |
# |    std                  | 0.983       |
# |    value_loss           | 0.000439    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -10.1       |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 15          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014447656 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000793    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 0.982       |
# |    value_loss           | 0.000464    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -9.94      |
# | time/                   |            |
# |    fps                  | 212        |
# |    iterations           | 16         |
# |    time_elapsed         | 153        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01631343 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.4      |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0232    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.019     |
# |    std                  | 0.982      |
# |    value_loss           | 0.000318   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -9.76       |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 17          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.012993824 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0229     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.981       |
# |    value_loss           | 0.000347    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -9.63       |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 18          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.014374834 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00476    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.98        |
# |    value_loss           | 0.000352    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -9.49       |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 19          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012364836 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0194     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.977       |
# |    value_loss           | 0.000287    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -9.36      |
# | time/                   |            |
# |    fps                  | 212        |
# |    iterations           | 20         |
# |    time_elapsed         | 192        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01384349 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.3      |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0012     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0125    |
# |    std                  | 0.976      |
# |    value_loss           | 0.000294   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -9.22       |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 21          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.014655825 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0271     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 0.974       |
# |    value_loss           | 0.000244    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -9.07        |
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 22           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0127480365 |
# |    clip_fraction        | 0.164        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.3        |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0112      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0125      |
# |    std                  | 0.977        |
# |    value_loss           | 0.00388      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.94       |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 23          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.013706545 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0371     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.975       |
# |    value_loss           | 0.000233    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.84       |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 24          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013661966 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0596     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.972       |
# |    value_loss           | 0.000734    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.73       |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 25          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.013447944 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00281    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0152     |
# |    std                  | 0.971       |
# |    value_loss           | 0.000284    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -8.61      |
# | time/                   |            |
# |    fps                  | 211        |
# |    iterations           | 26         |
# |    time_elapsed         | 251        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.01569787 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.2      |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0412    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0168    |
# |    std                  | 0.974      |
# |    value_loss           | 0.00035    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.45       |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 27          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.015638737 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.975       |
# |    value_loss           | 0.000194    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.32       |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 28          |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.015358502 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00212    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.969       |
# |    value_loss           | 0.000193    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.26       |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 29          |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011967342 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0242     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.972       |
# |    value_loss           | 0.00435     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.16       |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 30          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.016674332 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0297      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.97        |
# |    value_loss           | 0.000294    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.06       |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 31          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.019264169 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0339     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0207     |
# |    std                  | 0.971       |
# |    value_loss           | 0.000227    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.97       |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 32          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.014526965 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0018     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.973       |
# |    value_loss           | 0.000221    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.88       |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 33          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.015317507 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0146     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.975       |
# |    value_loss           | 0.000202    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -7.8       |
# | time/                   |            |
# |    fps                  | 203        |
# |    iterations           | 34         |
# |    time_elapsed         | 341        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.01752048 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.3      |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0259    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0176    |
# |    std                  | 0.975      |
# |    value_loss           | 0.000317   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.7        |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 35          |
# |    time_elapsed         | 350         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013707126 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00215    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.972       |
# |    value_loss           | 0.000207    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -7.6       |
# | time/                   |            |
# |    fps                  | 205        |
# |    iterations           | 36         |
# |    time_elapsed         | 358        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.01557701 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.2      |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0394    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0144    |
# |    std                  | 0.975      |
# |    value_loss           | 0.000128   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.54       |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 37          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.013119185 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0191     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.972       |
# |    value_loss           | 0.000165    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.45       |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 38          |
# |    time_elapsed         | 378         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.017216986 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00111    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.971       |
# |    value_loss           | 0.000161    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.37       |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 39          |
# |    time_elapsed         | 389         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.013416897 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 0.975       |
# |    value_loss           | 0.000126    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.31       |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 40          |
# |    time_elapsed         | 398         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011556312 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00949    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.975       |
# |    value_loss           | 0.00127     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -7.24      |
# | time/                   |            |
# |    fps                  | 206        |
# |    iterations           | 41         |
# |    time_elapsed         | 406        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.01322914 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.2      |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0125    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0156    |
# |    std                  | 0.972      |
# |    value_loss           | 0.000172   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -9.45       |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 42          |
# |    time_elapsed         | 413         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.015883427 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0455     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.969       |
# |    value_loss           | 0.000285    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -9.32       |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 43          |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.015124643 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.0118      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.97        |
# |    value_loss           | 19.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -9.2        |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 44          |
# |    time_elapsed         | 428         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.016011529 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.012      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.973       |
# |    value_loss           | 0.0013      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -9.09      |
# | time/                   |            |
# |    fps                  | 210        |
# |    iterations           | 45         |
# |    time_elapsed         | 437        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.01674334 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.2      |
# |    explained_variance   | 0.978      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00268    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0191    |
# |    std                  | 0.976      |
# |    value_loss           | 0.000787   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.98       |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 46          |
# |    time_elapsed         | 444         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.014906505 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -5.89e-05   |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.973       |
# |    value_loss           | 0.000465    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.87       |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 47          |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.020143276 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0196     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0197     |
# |    std                  | 0.971       |
# |    value_loss           | 0.000439    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -8.81      |
# | time/                   |            |
# |    fps                  | 214        |
# |    iterations           | 48         |
# |    time_elapsed         | 459        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.01596247 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.2      |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.017     |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0223    |
# |    std                  | 0.97       |
# |    value_loss           | 0.000416   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.72       |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 49          |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.018312182 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0218     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.968       |
# |    value_loss           | 0.00578     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.58       |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 50          |
# |    time_elapsed         | 476         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.016985467 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.1       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0128     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.967       |
# |    value_loss           | 0.000324    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.45       |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 51          |
# |    time_elapsed         | 484         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.014129862 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.1       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00524     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.968       |
# |    value_loss           | 0.000228    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.33       |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 52          |
# |    time_elapsed         | 491         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.017048694 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.1       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0341     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.962       |
# |    value_loss           | 0.000272    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.18       |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 53          |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.015433346 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# ...
# |    entropy_loss         | -20.4       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0231     |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.873       |
# |    value_loss           | 0.000485    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -6.76      |
# | time/                   |            |
# |    fps                  | 221        |
# |    iterations           | 131        |
# |    time_elapsed         | 1212       |
# |    total_timesteps      | 268288     |
# | train/                  |            |
# |    approx_kl            | 0.01762367 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -20.4      |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0409    |
# |    n_updates            | 1300       |
# |    policy_gradient_loss | -0.0163    |
# |    std                  | 0.872      |
# |    value_loss           | 0.000652   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.74       |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 132         |
# |    time_elapsed         | 1220        |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.019727059 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.4       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0095     |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.87        |
# |    value_loss           | 0.000558    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.73       |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 133         |
# |    time_elapsed         | 1227        |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.015898667 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.4       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00329     |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.0096     |
# |    std                  | 0.871       |
# |    value_loss           | 0.000354    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.75       |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 134         |
# |    time_elapsed         | 1235        |
# |    total_timesteps      | 274432      |
# | train/                  |             |
# |    approx_kl            | 0.015068286 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.3       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00596    |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.868       |
# |    value_loss           | 0.000384    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.76       |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 135         |
# |    time_elapsed         | 1245        |
# |    total_timesteps      | 276480      |
# | train/                  |             |
# |    approx_kl            | 0.022656478 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.3       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0174      |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.867       |
# |    value_loss           | 0.000246    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -6.77      |
# | time/                   |            |
# |    fps                  | 221        |
# |    iterations           | 136        |
# |    time_elapsed         | 1260       |
# |    total_timesteps      | 278528     |
# | train/                  |            |
# |    approx_kl            | 0.02033132 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -20.3      |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0167    |
# |    n_updates            | 1350       |
# |    policy_gradient_loss | -0.0179    |
# |    std                  | 0.863      |
# |    value_loss           | 0.000275   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.76       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 137         |
# |    time_elapsed         | 1270        |
# |    total_timesteps      | 280576      |
# | train/                  |             |
# |    approx_kl            | 0.013535004 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.2       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0325     |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.863       |
# |    value_loss           | 0.000165    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -6.74      |
# | time/                   |            |
# |    fps                  | 220        |
# |    iterations           | 138        |
# |    time_elapsed         | 1279       |
# |    total_timesteps      | 282624     |
# | train/                  |            |
# |    approx_kl            | 0.01638641 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -20.2      |
# |    explained_variance   | 0.99       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0215    |
# |    n_updates            | 1370       |
# |    policy_gradient_loss | -0.0127    |
# |    std                  | 0.862      |
# |    value_loss           | 0.000189   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.75       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 139         |
# |    time_elapsed         | 1289        |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.017430339 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.2       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0239     |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.861       |
# |    value_loss           | 0.000222    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.76       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 140         |
# |    time_elapsed         | 1299        |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.019931281 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.1       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0257     |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.856       |
# |    value_loss           | 0.000217    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.74       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 141         |
# |    time_elapsed         | 1309        |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.021726986 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.1       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0212      |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.853       |
# |    value_loss           | 0.000232    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -6.74      |
# | time/                   |            |
# |    fps                  | 220        |
# |    iterations           | 142        |
# |    time_elapsed         | 1317       |
# |    total_timesteps      | 290816     |
# | train/                  |            |
# |    approx_kl            | 0.01924859 |
# |    clip_fraction        | 0.226      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -20        |
# |    explained_variance   | 0.99       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0277    |
# |    n_updates            | 1410       |
# |    policy_gradient_loss | -0.0189    |
# |    std                  | 0.855      |
# |    value_loss           | 0.000146   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.74       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 143         |
# |    time_elapsed         | 1327        |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.020060275 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.1       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0209     |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.855       |
# |    value_loss           | 0.00022     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.66       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 144         |
# |    time_elapsed         | 1336        |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.020778548 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.1       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.04       |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | -0.0208     |
# |    std                  | 0.856       |
# |    value_loss           | 0.000143    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.85       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 145         |
# |    time_elapsed         | 1346        |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.015637854 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20         |
# |    explained_variance   | 0.31        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0367     |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.852       |
# |    value_loss           | 0.157       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.85       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 146         |
# |    time_elapsed         | 1356        |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.025101941 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20         |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0345     |
# |    n_updates            | 1450        |
# |    policy_gradient_loss | -0.0201     |
# |    std                  | 0.855       |
# |    value_loss           | 0.00121     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.86       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 147         |
# |    time_elapsed         | 1365        |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.018857285 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.1       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0334     |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | -0.0194     |
# |    std                  | 0.859       |
# |    value_loss           | 0.0014      |
# -----------------------------------------

# %%
episodes = 10
x = []
for ep in range(episodes):
    rewards = 0
    state = env.reset()[0]
    while True:
        # env.render()
        action = model2.predict(state)[0]
        state, reward, done, truncuated, info = env.step(action)
        rewards += reward
        if done or truncuated:
            break
    h = env.kf.A - A
    x.append(h)

# %%
# Out:
# Array([[-1.5120112 , -3.0536647 , -2.5878775 ,  2.1101022 ],
#        [-0.64700586,  2.9988332 , -2.6241379 , -1.1773218 ],
#        [-0.66021204, -2.5274637 , -2.9931839 ,  0.14226285],
#        [ 2.9931576 ,  0.360365  , -3.6396477 , -1.1661142 ]],      dtype=float32)
